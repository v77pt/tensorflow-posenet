# %%
import test

# %%
test.main()
# Out:
# ...
# 100%|██████████| 343/343 [00:00<00:00, 1141.98it/s]
# INFO:tensorflow:Restoring parameters from D:/PythonWorkSpace/posenet/tensorflow-posenet/weights/PoseNet.ckpt
# Iteration:   0   Error XYZ (m):   1.72649169487   Error Q (degrees):   2.14106533736
# Iteration:   1   Error XYZ (m):   1.0935199474   Error Q (degrees):   0.910094878682
# Iteration:   2   Error XYZ (m):   1.17596472413   Error Q (degrees):   2.33314387421
# Iteration:   3   Error XYZ (m):   1.8488590171   Error Q (degrees):   1.43012005365
# Iteration:   4   Error XYZ (m):   2.03158845658   Error Q (degrees):   1.37408222741
# Iteration:   5   Error XYZ (m):   1.59569774823   Error Q (degrees):   2.62245137955
# Iteration:   6   Error XYZ (m):   1.15568620282   Error Q (degrees):   0.427830534028
# Iteration:   7   Error XYZ (m):   1.52448758632   Error Q (degrees):   1.48127283769
# Iteration:   8   Error XYZ (m):   3.0435964039   Error Q (degrees):   2.7981507486
# ...
